# %% [markdown]
# <a href="https://colab.research.google.com/github/Yhadiii26/sentimientos/blob/main/sentimientos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv('dataset_train.csv')

# %%
df.isnull().sum()
# Out:
# id            0
# user          0
# text          0
# date          0
# emotion       0
# sentimento    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,  y_train, y_test=train_test_split(df['text']+ '' + df['emotion'],df['sentimento'],test_size=0.25)

# %%
from sklearn.feature_extraction.text import CountVectorizer


vectorizador = CountVectorizer()
x_train_vec = vectorizador.fit_transform(x_train)
x_test_vec = vectorizador.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(x_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

predict = modelo.predict(x_test_vec)
accuracy = accuracy_score(y_test,predict)
print(accuracy)
# Out:
# 0.8976833976833977

# %%
df_test = pd.read_csv('dataset_test_sin_sentimento.csv')
df_test.head()
# Out:
#      id             user                                               text  \
# 0  1836        @awjdrm84  Bravos es el verdadero medidor de Leones, con ...
# 1  2502  @alejandracinco                                  Bien atrevido yop
# 2  1561    @JuliiRojas_m  Es increíble la capacidad de recordar momentos...
# 3   393    @anac_atencia  Quiero unos patines, ese siempre ha sido mi re...
# 4   677          @cldyqs               PQ ESTA TAN DISTANTE ME WUIEO4 MATAT
#
#                          date    emotion
# 0   Jan 6, 2024 · 3:33 AM UTC  confident
# 1   Jan 6, 2024 · 3:04 AM UTC     daring
# 2  Jan 2, 2024 · 11:20 AM UTC   thankful
# 3   Jan 6, 2024 · 3:33 AM UTC    jealous
# 4   Jan 6, 2024 · 3:27 AM UTC    distant

# %%
df_test.isnull().sum()
# Out:
# id         0
# user       0
# text       0
# date       0
# emotion    0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer


nueva= df_test['text']+ ' ' + df_test['emotion']
X_nueva = vectorizador.transform(nueva)
resultado= modelo.predict(X_nueva)

df_test['etiqueta']= resultado

df_test.head()
# Out:
#      id             user                                               text  \
# 0  1836        @awjdrm84  Bravos es el verdadero medidor de Leones, con ...
# 1  2502  @alejandracinco                                  Bien atrevido yop
# 2  1561    @JuliiRojas_m  Es increíble la capacidad de recordar momentos...
# 3   393    @anac_atencia  Quiero unos patines, ese siempre ha sido mi re...
# 4   677          @cldyqs               PQ ESTA TAN DISTANTE ME WUIEO4 MATAT
#
#                          date    emotion  etiqueta
# 0   Jan 6, 2024 · 3:33 AM UTC  confident         1
# 1   Jan 6, 2024 · 3:04 AM UTC     daring         1
# 2  Jan 2, 2024 · 11:20 AM UTC   thankful         1
# 3   Jan 6, 2024 · 3:33 AM UTC    jealous         0
# 4   Jan 6, 2024 · 3:27 AM UTC    distant         0

# %%
output = pd.DataFrame({'id': df_test['id'], 'etiqueta': resultado})
output.to_csv('submission3.csv', index=False)
